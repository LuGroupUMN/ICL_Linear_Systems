# %%
import matplotlib.pyplot as plt
import numpy as np

### Plots for diversity l2
npy_name = 'Elliptic_Result_diversity_test.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, para_ls, op_l2_mat, op_h1_mat, bad_l2_mat, bad_h1_mat = loaded_items

plt.rcParams.update({
    'font.size': 14,          # base font size
    'axes.titlesize': 16,     # subplot title
    'axes.labelsize': 14,     # x and y labels
    'xtick.labelsize': 12,    # x tick labels
    'ytick.labelsize': 12,    # y tick labels
    'legend.fontsize': 12,    # legend
    'figure.titlesize': 18    # figure title (if using suptitle)
})


fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].loglog(m_ls, op_l2_mat[0, ...], label=r'$V(x)=c \mathbf{I}, c \sim U(10,20)$')
for i in range(1, len(para_ls)):
    axs[0].loglog(m_ls, op_l2_mat[i, ...], '--*', label=rf'$V(x) \sim \mathbf{{U}}({str(1*para_ls[i][0])},{str(1*para_ls[i][1])})$')
axs[0].set_xlabel(r'$m$', fontsize=18)
axs[0].legend(fontsize=10)

axs[1].loglog(m_ls, bad_l2_mat[0, ...], label=r'$V(x)=c \mathbf{I}, c \sim U(10,20)$')
for i in range(1, len(para_ls)):
    axs[1].loglog(m_ls, bad_l2_mat[i, ...], '--*', label=rf'$V(x) \sim \mathbf{{U}}({str(1*para_ls[i][0])},{str(1*para_ls[i][1])})$')
axs[1].set_xlabel(r'$m$', fontsize=18)
#axs[1].set_ylim([3e-2, 3e-1])
axs[1].legend(fontsize=10)
plt.tight_layout()
plt.savefig(f'Elliptic_diversity_l2.png', bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

### Plots for diversity H1
npy_name = 'Elliptic_Result_diversity_test.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, para_ls, op_l2_mat, op_h1_mat, bad_l2_mat, bad_h1_mat = loaded_items

plt.rcParams.update({
    'font.size': 14,          # base font size
    'axes.titlesize': 16,     # subplot title
    'axes.labelsize': 14,     # x and y labels
    'xtick.labelsize': 12,    # x tick labels
    'ytick.labelsize': 12,    # y tick labels
    'legend.fontsize': 12,    # legend
    'figure.titlesize': 18    # figure title (if using suptitle)
})


fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].loglog(m_ls, op_h1_mat[0, ...], label=r'$V(x)=c \mathbf{I}, c \sim U(10,20)$')
for i in range(1, len(para_ls)):
    axs[0].loglog(m_ls, op_h1_mat[i, ...], '--*', label=rf'$V(x) \sim \mathbf{{U}}({str(1*para_ls[i][0])},{str(1*para_ls[i][1])})$')
axs[0].set_xlabel(r'$m$', fontsize=18)
#axs[0].set_ylim([4e-2, 7e-1])
axs[0].legend(fontsize=10, loc='lower left')

axs[1].loglog(m_ls, op_h1_mat[0, ...], label=r'$V(x)=c \mathbf{I}, c \sim U(10,20)$')
for i in range(1, len(para_ls)):
    axs[1].loglog(m_ls, bad_h1_mat[i, ...], '--*', label=rf'$V(x) \sim \mathbf{{U}}({str(1*para_ls[i][0])},{str(1*para_ls[i][1])})$')
axs[1].set_xlabel(r'$m$', fontsize=18)
#axs[1].set_ylim([4e-2, 7e-1])
axs[1].legend(fontsize=10, loc='lower left')
plt.tight_layout()
plt.savefig(f'Elliptic_diversity_h1.png', bbox_inches = 'tight')
plt.show()

# %%
### plots for OOD
import matplotlib.pyplot as plt
import numpy as np

### Load a
npy_name = 'Elliptic_Result_OOD_test_a.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, a_para_ls, a_l2_mat, a_h1_mat = loaded_items

### Load V
npy_name = 'Elliptic_Result_OOD_test_V.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, V_para_ls, V_l2_mat, V_h1_mat = loaded_items

### Load f
npy_name = 'Elliptic_Result_OOD_test_f.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, f_para_ls, f_l2_mat, f_h1_mat = loaded_items

plt.rcParams.update({
    'font.size': 14,          # base font size
    'axes.titlesize': 16,     # subplot title
    'axes.labelsize': 14,     # x and y labels
    'xtick.labelsize': 12,    # x tick labels
    'ytick.labelsize': 12,    # y tick labels
    'legend.fontsize': 12,    # legend
    'figure.titlesize': 18    # figure title (if using suptitle)
})


fig, axs = plt.subplots(2, 3, figsize=(15, 8))

### for a
axs[0, 0].loglog(m_ls, a_l2_mat[0, ...], label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[0][0])+','+str(a_para_ls[0][1])+')')
for i in range(1, len(a_para_ls)//2+1):
    axs[0, 0].loglog(m_ls, a_l2_mat[i, ...], '--*', label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[i][0])+','+str(a_para_ls[i][1])+')')

axs[0, 0].set_xlabel(r'$m$', fontsize=18)
axs[0, 0].set_title(r'Shift in $a(x)$', fontsize=18)
axs[0, 0].legend(fontsize=12)

axs[1, 0].loglog(m_ls, a_l2_mat[0, ...], label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[0][0])+','+str(a_para_ls[0][1])+')')
for i in range(len(a_para_ls)//2+1, len(a_para_ls)):
    axs[1, 0].loglog(m_ls, a_l2_mat[i, ...], '--*', label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[i][0])+','+str(a_para_ls[i][1])+')')

axs[1, 0].set_xlabel(r'$m$', fontsize=18)
axs[1, 0].legend(fontsize=12)

### for V
axs[0, 1].loglog(m_ls, V_l2_mat[0, ...], label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[0][0])+','+str(V_para_ls[0][1])+')')
for i in range(1, len(V_para_ls)//2+1):
    axs[0, 1].loglog(m_ls, V_l2_mat[i, ...], '--*', label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[i][0])+','+str(V_para_ls[i][1])+')')

axs[0, 1].set_xlabel(r'$m$', fontsize=18)
axs[0, 1].set_title(r'Shift in $V(x)$', fontsize=18)
axs[0, 1].legend(fontsize=12)

axs[1, 1].loglog(m_ls, V_l2_mat[0, ...], label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[0][0])+','+str(V_para_ls[0][1])+')')
for i in range(len(V_para_ls)//2+1, len(V_para_ls)):
    axs[1, 1].loglog(m_ls, a_l2_mat[i, ...], '--*', label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[i][0])+','+str(V_para_ls[i][1])+')')

axs[1, 1].set_xlabel(r'$m$', fontsize=18)
axs[1, 1].legend(fontsize=12)


### for f
axs[0, 2].loglog(m_ls, f_l2_mat[0, ...], label=rf'$(\alpha_3,\beta_3)=$(' + str(f_para_ls[0][0])+','+str(f_para_ls[0][1])+')')
for i in range(1, len(f_para_ls)//2+1):
    axs[0, 2].loglog(m_ls, f_l2_mat[i, ...], '--*', label=rf'$(\alpha_3,\beta_3)=$(' + str(f_para_ls[i][0])+','+str(f_para_ls[i][1])+')')

axs[0, 2].set_xlabel(r'$m$', fontsize=18)
axs[0, 2].set_title(r'Shift in $f(x)$', fontsize=18)
axs[0, 2].legend(fontsize=12, loc='upper center',
    bbox_to_anchor=(0.5, 0.85))

axs[1, 2].loglog(m_ls, f_l2_mat[0, ...], label=rf'$(\alpha_3,\beta_3)=$(' + str(f_para_ls[0][0])+','+str(f_para_ls[0][1])+')')
for i in range(len(f_para_ls)//2+1, len(f_para_ls)):
    axs[1, 2].loglog(m_ls, f_l2_mat[i, ...], '--*', label=rf'$(\alpha_3,\beta_3)=$(' + str(a_para_ls[i][0])+','+str(a_para_ls[i][1])+')')

axs[1, 2].set_xlabel(r'$m$', fontsize=18)
axs[1, 2].legend(fontsize=12)


plt.tight_layout()
plt.savefig(f'Elliptic_OOD_l2.png', bbox_inches = 'tight')
plt.show()

# %%
### plots for OOD
import matplotlib.pyplot as plt
import numpy as np

### Load a
npy_name = 'Elliptic_Result_OOD_test_a.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, a_para_ls, a_l2_mat, a_h1_mat = loaded_items

### Load V
npy_name = 'Elliptic_Result_OOD_test_V.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, V_para_ls, V_l2_mat, V_h1_mat = loaded_items

### Load f
npy_name = 'Elliptic_Result_OOD_test_f.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_ls, f_para_ls, f_l2_mat, f_h1_mat = loaded_items

plt.rcParams.update({
    'font.size': 14,          # base font size
    'axes.titlesize': 16,     # subplot title
    'axes.labelsize': 14,     # x and y labels
    'xtick.labelsize': 12,    # x tick labels
    'ytick.labelsize': 12,    # y tick labels
    'legend.fontsize': 12,    # legend
    'figure.titlesize': 18    # figure title (if using suptitle)
})


fig, axs = plt.subplots(2, 3, figsize=(15, 8))

### for a
axs[0, 0].loglog(m_ls, a_h1_mat[0, ...], label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[0][0])+','+str(a_para_ls[0][1])+')')
for i in range(1, len(a_para_ls)//2+1):
    axs[0, 0].loglog(m_ls, a_h1_mat[i, ...], '--*', label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[i][0])+','+str(a_para_ls[i][1])+')')

axs[0, 0].set_xlabel(r'$m$', fontsize=18)
axs[0, 0].legend(fontsize=12, loc='lower left')

axs[1, 0].loglog(m_ls, a_h1_mat[0, ...], label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[0][0])+','+str(a_para_ls[0][1])+')')
for i in range(len(a_para_ls)//2+1, len(a_para_ls)):
    axs[1, 0].loglog(m_ls, a_h1_mat[i, ...], '--*', label=rf'$(\alpha_1,\beta_1)=$(' + str(a_para_ls[i][0])+','+str(a_para_ls[i][1])+')')

axs[1, 0].set_xlabel(r'$m$', fontsize=18)
axs[1, 0].legend(fontsize=12, loc='lower left')

### for V
axs[0, 1].loglog(m_ls, V_h1_mat[0, ...], label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[0][0])+','+str(V_para_ls[0][1])+')')
for i in range(1, len(V_para_ls)//2+1):
    axs[0, 1].loglog(m_ls, V_h1_mat[i, ...], '--*', label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[i][0])+','+str(V_para_ls[i][1])+')')

axs[0, 1].set_xlabel(r'$m$', fontsize=18)
axs[0, 1].legend(fontsize=12, loc='lower left')

axs[1, 1].loglog(m_ls, V_h1_mat[0, ...], label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[0][0])+','+str(V_para_ls[0][1])+')')
for i in range(len(V_para_ls)//2+1, len(V_para_ls)):
    axs[1, 1].loglog(m_ls, a_h1_mat[i, ...], '--*', label=rf'$(\alpha_2,\beta_2)=$(' + str(V_para_ls[i][0])+','+str(V_para_ls[i][1])+')')

axs[1, 1].set_xlabel(r'$m$', fontsize=18)
axs[1, 1].legend(fontsize=12, loc='lower left')


### for f
axs[0, 2].loglog(m_ls, f_h1_mat[0, ...], label=rf'$(\alpha_3,\beta_3)=$(' + str(f_para_ls[0][0])+','+str(f_para_ls[0][1])+')')
for i in range(1, len(f_para_ls)//2+1):
    axs[0, 2].loglog(m_ls, f_h1_mat[i, ...], '--*', label=rf'$(\alpha_3,\beta_3)=$(' + str(f_para_ls[i][0])+','+str(f_para_ls[i][1])+')')

axs[0, 2].set_xlabel(r'$m$', fontsize=18)
axs[0, 2].legend(fontsize=12, loc='upper center',
    bbox_to_anchor=(0.5, 0.85),)

axs[1, 2].loglog(m_ls, f_h1_mat[0, ...], label=rf'$(\alpha_3,\beta_3)=$(' + str(f_para_ls[0][0])+','+str(f_para_ls[0][1])+')')
for i in range(len(f_para_ls)//2+1, len(f_para_ls)):
    axs[1, 2].loglog(m_ls, f_h1_mat[i, ...], '--*', label=rf'$(\alpha_3,\beta_3)=$(' + str(a_para_ls[i][0])+','+str(a_para_ls[i][1])+')')

import matplotlib.ticker as ticker

# axs[1, 2].set_ylim([0.045, 0.5])
# axs[1, 2].set_yscale('log')
# axs[1, 2].yaxis.set_major_locator(ticker.FixedLocator([0.05, 0.1, 0.2, 0.4]))
# axs[1, 2].yaxis.set_minor_locator(ticker.NullLocator())
# #axs[1, 2].ticklabel_format(axis='y', style='sci', scilimits=(0,0))
# axs[1, 2].set_xlabel(r'$m$', fontsize=18)
# axs[1, 2].legend(fontsize=12)

ax = axs[1, 2]
ax.set_yscale('log')
ax.set_ylim(0.04, 0.5)

ax.yaxis.set_major_locator(ticker.FixedLocator([0.06, 0.2, 0.4]))
ax.yaxis.set_minor_locator(ticker.NullLocator())
def sci_formatter(x, pos):
    e = int(np.floor(np.log10(x)))
    m = x / 10**e
    # use :g to trim trailing zeros
    return rf'${m:g}\times10^{{{e}}}$'

ax.yaxis.set_major_formatter(ticker.FuncFormatter(sci_formatter))
axs[1, 2].set_xlabel(r'$m$', fontsize=18)
axs[1, 2].legend(fontsize=12)


axs[0,0].set_title(r'Shift in  $a(x)$', fontsize=18)
axs[0,1].set_title(r'Shift in  $V(x)$', fontsize=18)
axs[0,2].set_title(r'Shift in  $f(x)$', fontsize=18)

plt.tight_layout()
plt.savefig(f'Elliptic_OOD_h1.png', bbox_inches = 'tight')
plt.show()

# %%
### plots for IND
import matplotlib.pyplot as plt
import numpy as np

### Load sn
npy_name = 'Elliptic_Result_test_sn.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
n_n_ls, n_m_ls, n_mse_mat, n_mse_ref_rate, n_h1_mat, n_h1_ref_rate = loaded_items

### Load m
npy_name = 'Elliptic_Result_test_m.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_m_ls, m_n_ls, m_mse_mat, m_mse_ref_rate, m_h1_mat, m_h1_ref_rate = loaded_items

### Load N
npy_name = 'Elliptic_Result_test_N.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
N_N_ls, N_m_ls, N_mse_mat, N_mse_ref_rate, N_h1_mat, N_h1_ref_rate = loaded_items



plt.rcParams.update({
    'font.size': 14,          # base font size
    'axes.titlesize': 16,     # subplot title
    'axes.labelsize': 14,     # x and y labels
    'xtick.labelsize': 12,    # x tick labels
    'ytick.labelsize': 12,    # y tick labels
    'legend.fontsize': 12,    # legend
    'figure.titlesize': 18    # figure title (if using suptitle)
})


fig, axs = plt.subplots(1, 3, figsize=(15, 4))

### for n
for i in range(len(n_m_ls)):
    axs[0].loglog(n_n_ls, n_mse_mat[i, ...], '--*', label=f'm={n_m_ls[i]}')

axs[0].loglog(n_n_ls, n_mse_ref_rate, 'b', label=r'$O(n^{-2})$')
axs[0].set_xlabel(r'$n$', fontsize=18)
axs[0].legend(fontsize=12)

### for m
for i in range(len(m_n_ls)):
    axs[1].loglog(m_m_ls, m_mse_mat[i, ...], '--*', label=f'n={m_n_ls[i]}')

axs[1].loglog(m_m_ls, m_mse_ref_rate, 'b', label=r'$O(m^{-1})$')
axs[1].set_xlabel(r'$m$', fontsize=18)
axs[1].legend(fontsize=12)

### for N
for i in range(len(N_m_ls)):
    axs[2].loglog(N_N_ls, N_mse_mat[i, ...], '--*', label=f'm={N_m_ls[i]}')

axs[2].loglog(N_N_ls, 4*N_mse_ref_rate, 'b', label=r'$O(N^{-1})$')
axs[2].set_xlabel(r'$N$', fontsize=18)
axs[2].legend(fontsize=12)

plt.tight_layout()
plt.savefig(f'Elliptic_IND_l2.png', bbox_inches = 'tight')
plt.show()

# %%
### plots for IND
import matplotlib.pyplot as plt
import numpy as np

### Load sn
npy_name = 'Elliptic_Result_test_sn.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
n_n_ls, n_m_ls, n_mse_mat, n_mse_ref_rate, n_h1_mat, n_h1_ref_rate = loaded_items

### Load m
npy_name = 'Elliptic_Result_test_m.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
m_m_ls, m_n_ls, m_mse_mat, m_mse_ref_rate, m_h1_mat, m_h1_ref_rate = loaded_items

### Load N
npy_name = 'Elliptic_Result_test_N.npy'
loaded_items = []
with open(npy_name, 'rb') as f:
    while True:
        try:
            item = np.load(f)
            loaded_items.append(item)
        except EOFError:
            break
N_N_ls, N_m_ls, N_mse_mat, N_mse_ref_rate, N_h1_mat, N_h1_ref_rate = loaded_items



plt.rcParams.update({
    'font.size': 14,          # base font size
    'axes.titlesize': 16,     # subplot title
    'axes.labelsize': 14,     # x and y labels
    'xtick.labelsize': 12,    # x tick labels
    'ytick.labelsize': 12,    # y tick labels
    'legend.fontsize': 12,    # legend
    'figure.titlesize': 18    # figure title (if using suptitle)
})


fig, axs = plt.subplots(1, 3, figsize=(15, 4))

### for n
for i in range(len(n_m_ls)):
    axs[0].loglog(n_n_ls, n_h1_mat[i, ...], '--*', label=f'm={n_m_ls[i]}')

axs[0].loglog(n_n_ls, n_h1_ref_rate, 'b', label=r'$O(n^{-2})$')
axs[0].set_xlabel(r'$n$', fontsize=18)
axs[0].legend(fontsize=12, loc='lower left')

### for m
for i in range(len(m_n_ls)):
    axs[1].loglog(m_m_ls, m_h1_mat[i, ...], '--*', label=f'n={m_n_ls[i]}')

axs[1].loglog(m_m_ls, m_h1_ref_rate, 'b', label=r'$O(m^{-1})$')
axs[1].set_xlabel(r'$m$', fontsize=18)
axs[1].legend(fontsize=12, loc='lower left')

### for N
for i in range(len(N_m_ls)):
    axs[2].loglog(N_N_ls, N_h1_mat[i, ...], '--*', label=f'm={N_m_ls[i]}')
axs[2].loglog(N_N_ls, 4*N_h1_ref_rate, 'b', label=r'$O(N^{-1})$')
axs[2].set_xlabel(r'$N$', fontsize=18)
axs[2].legend(fontsize=12, loc='lower left')
plt.tight_layout()
plt.savefig(f'Elliptic_IND_h1.png', bbox_inches = 'tight')
plt.show()
